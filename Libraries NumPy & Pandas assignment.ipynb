# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Q1. Load the given retail sales dataset into a Pandas DataFrame and display the first 5 rows along with the
# dataset information to understand its structure.

# %%
# Load dataset
df = pd.read_csv("/content/retail_dataset .csv")

# Display first 5 rows
print(df.head())

# Dataset info
print(df.info())

#Remove extra space fromm column name
df.columns = df.columns.str.replace(" ","_")
print(df.info())
# Out:
#   Transaction ID Customer ID Product Category  Quantity   Price        Date  \
# 0           T001        C015            Books       7.0   167.0  02-02-2023
# 1           T002        C004             Toys       4.0   374.0  17-02-2023
# 2           T003        C033        Furniture       8.0  1059.0  17-05-2024
# 3           T004        C047        Groceries       5.0   304.0  11-02-2024
# 4           T005        C022            Books       7.0   282.0  27-07-2024
#
#   Region
# 0  North
# 1  South
# 2  South
# 3  South
# 4   West
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    100 non-null    object
#  1   Customer ID       100 non-null    object
#  2   Product Category  97 non-null     object
#  3   Quantity          98 non-null     float64
#  4   Price             95 non-null     float64
#  5   Date              100 non-null    object
#  6   Region            98 non-null     object
# dtypes: float64(2), object(5)
# memory usage: 5.6+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction_ID    100 non-null    object
#  1   Customer_ID       100 non-null    object
#  2   Product_Category  97 non-null     object
#  3   Quantity          98 non-null     float64
#  4   Price             95 non-null     float64
#  5   Date              100 non-null    object
#  6   Region            98 non-null     object
# dtypes: float64(2), object(5)
# memory usage: 5.6+ KB
# None

# %% [markdown]
# Q2. Inspect the dataset and identify missing values in each column. Display the total number of missing
# values present in the dataset.

# %%
# Count missing values per column
print(df.isnull().sum())
# Out:
# Transaction ID      0
# Customer ID         0
# Product Category    3
# Quantity            2
# Price               5
# Date                0
# Region              2
# dtype: int64

# %%
# Total missing values
print("Total missing values:", df.isnull().sum().sum())
# Out:
# Total missing values: 12

# %% [markdown]
# Q3. Replace missing values in the Quantity and Price columns with their respective mean values using
# Pandas.

# %%
#Replace missing value in quantity column
df['Quantity'] = df['Quantity'].fillna(df['Quantity'].mean())
print(df.head(20))
# Out:
#    Transaction ID Customer ID Product Category  Quantity        Price  \
# 0            T001        C015            Books       7.0   167.000000
# 1            T002        C004             Toys       4.0   374.000000
# 2            T003        C033        Furniture       8.0  1059.000000
# 3            T004        C047        Groceries       5.0   304.000000
# 4            T005        C022            Books       7.0   282.000000
# 5            T006        C042      Electronics      10.0   866.000000
# 6            T007        C022        Furniture       3.0  2340.000000
# 7            T008        C023         Clothing       7.0   881.000000
# 8            T009        C008      Electronics       8.0   780.000000
# 9            T010        C003        Furniture       5.0  1617.000000
# 10           T011        C003      Electronics       4.0   820.526316
# 11           T012        C046           Beauty       8.0   149.000000
# 12           T013        C043              NaN       8.0   510.000000
# 13           T014        C029             Toys       3.0   344.000000
# 14           T015        C010           Sports       6.0   803.000000
# 15           T016        C029         Clothing       5.0   639.000000
# 16           T017        C004             Toys       2.0   423.000000
# 17           T018        C039             Toys       8.0   820.526316
# 18           T019        C022           Sports       6.0  1328.000000
# 19           T020        C045             Toys       2.0   962.000000
#
#           Date Region
# 0   02-02-2023  North
# 1   17-02-2023  South
# 2   17-05-2024  South
# 3   11-02-2024  South
# 4   27-07-2024   West
# 5   28-12-2024   West
# 6   09-04-2023   East
# 7   14-11-2024   West
# 8   26-12-2024   East
# 9   30-06-2024  North
# 10  04-09-2024   East
# 11  06-04-2024   West
# 12  04-10-2024   East
# 13  05-01-2023   West
# 14  06-08-2023   East
# 15  17-05-2024  North
# 16  02-02-2024  South
# 17  28-01-2024    NaN
# 18  26-07-2023   East
# 19  15-01-2023  South

# %%
#Replace missing value in price column
df['Price'] = df['Price'].fillna(df['Price'].mean())
print(df.head(20))
# Out:
#    Transaction ID Customer ID Product Category  Quantity        Price  \
# 0            T001        C015            Books       7.0   167.000000
# 1            T002        C004             Toys       4.0   374.000000
# 2            T003        C033        Furniture       8.0  1059.000000
# 3            T004        C047        Groceries       5.0   304.000000
# 4            T005        C022            Books       7.0   282.000000
# 5            T006        C042      Electronics      10.0   866.000000
# 6            T007        C022        Furniture       3.0  2340.000000
# 7            T008        C023         Clothing       7.0   881.000000
# 8            T009        C008      Electronics       8.0   780.000000
# 9            T010        C003        Furniture       5.0  1617.000000
# 10           T011        C003      Electronics       4.0   820.526316
# 11           T012        C046           Beauty       8.0   149.000000
# 12           T013        C043              NaN       8.0   510.000000
# 13           T014        C029             Toys       3.0   344.000000
# 14           T015        C010           Sports       6.0   803.000000
# 15           T016        C029         Clothing       5.0   639.000000
# 16           T017        C004             Toys       2.0   423.000000
# 17           T018        C039             Toys       8.0   820.526316
# 18           T019        C022           Sports       6.0  1328.000000
# 19           T020        C045             Toys       2.0   962.000000
#
#           Date Region
# 0   02-02-2023  North
# 1   17-02-2023  South
# 2   17-05-2024  South
# 3   11-02-2024  South
# 4   27-07-2024   West
# 5   28-12-2024   West
# 6   09-04-2023   East
# 7   14-11-2024   West
# 8   26-12-2024   East
# 9   30-06-2024  North
# 10  04-09-2024   East
# 11  06-04-2024   West
# 12  04-10-2024   East
# 13  05-01-2023   West
# 14  06-08-2023   East
# 15  17-05-2024  North
# 16  02-02-2024  South
# 17  28-01-2024    NaN
# 18  26-07-2023   East
# 19  15-01-2023  South

# %% [markdown]
# Q4. Remove all rows where the Product Category or Region column contains missing values.

# %%
#Null value in Product_Category
df.Product_Category.unique()
# Out:
# array(['Books', 'Toys', 'Furniture', 'Groceries', 'Electronics',
#        'Clothing', 'Beauty', nan, 'Sports'], dtype=object)

# %%
#Null value in Region
df.Region.unique()
# Out:
# array(['North', 'South', 'West', 'East', nan], dtype=object)

# %%
#Remove row from Product_Category and Region Value
df = df.dropna(subset=['Product_Category', 'Region'])
print(df.head(25))
# Out:
#    Transaction_ID Customer_ID Product_Category  Quantity   Price        Date  \
# 0            T001        C015            Books       7.0   167.0  02-02-2023
# 1            T002        C004             Toys       4.0   374.0  17-02-2023
# 2            T003        C033        Furniture       8.0  1059.0  17-05-2024
# 3            T004        C047        Groceries       5.0   304.0  11-02-2024
# 4            T005        C022            Books       7.0   282.0  27-07-2024
# 5            T006        C042      Electronics      10.0   866.0  28-12-2024
# 6            T007        C022        Furniture       3.0  2340.0  09-04-2023
# 7            T008        C023         Clothing       7.0   881.0  14-11-2024
# 8            T009        C008      Electronics       8.0   780.0  26-12-2024
# 9            T010        C003        Furniture       5.0  1617.0  30-06-2024
# 10           T011        C003      Electronics       4.0     NaN  04-09-2024
# 11           T012        C046           Beauty       8.0   149.0  06-04-2024
# 13           T014        C029             Toys       3.0   344.0  05-01-2023
# 14           T015        C010           Sports       6.0   803.0  06-08-2023
# 15           T016        C029         Clothing       5.0   639.0  17-05-2024
# 16           T017        C004             Toys       2.0   423.0  02-02-2024
# 18           T019        C022           Sports       6.0  1328.0  26-07-2023
# 19           T020        C045             Toys       2.0   962.0  15-01-2023
# 20           T021        C043            Books       NaN   516.0  07-07-2024
# 21           T022        C042      Electronics       1.0  1971.0  05-04-2024
# 22           T023        C015           Beauty      10.0   174.0  21-11-2024
# 23           T024        C012         Clothing       6.0   236.0  28-07-2024
# 24           T025        C022      Electronics       9.0   751.0  29-08-2023
# 25           T026        C023           Sports       1.0   902.0  17-07-2024
# 26           T027        C016             Toys      10.0  1039.0  06-04-2023
#
#    Region
# 0   North
# 1   South
# 2   South
# 3   South
# 4    West
# 5    West
# 6    East
# 7    West
# 8    East
# 9   North
# 10   East
# 11   West
# 13   West
# 14   East
# 15  North
# 16  South
# 18   East
# 19  South
# 20   East
# 21   East
# 22  North
# 23   West
# 24  South
# 25   West
# 26  North

# %% [markdown]
# Q5. Create a new column called Revenue using NumPy, where:
#
# Revenue = Quantity × Price
#
# Display the updated dataset with the new column.

# %%
df['Revenue'] = df['Quantity'] * df['Price']
print(df.head())
# Out:
#   Transaction_ID Customer_ID Product_Category  Quantity   Price        Date  \
# 0           T001        C015            Books       7.0   167.0  02-02-2023
# 1           T002        C004             Toys       4.0   374.0  17-02-2023
# 2           T003        C033        Furniture       8.0  1059.0  17-05-2024
# 3           T004        C047        Groceries       5.0   304.0  11-02-2024
# 4           T005        C022            Books       7.0   282.0  27-07-2024
#
#   Region  Revenue
# 0  North   1169.0
# 1  South   1496.0
# 2  South   8472.0
# 3  South   1520.0
# 4   West   1974.0

# %% [markdown]
# Q6. Using NumPy, calculate the total revenue generated from all transactions in the dataset.

# %%
total_revenue = np.sum(df['Revenue'])
print("Total Revenue:", total_revenue)
# Out:
# Total Revenue: 443110.0

# %% [markdown]
# Q7. Group the dataset by Product Category and calculate the total revenue generated by each category.

# %%
category_revenue = df.groupby('Product_Category')['Revenue'].sum()
print(category_revenue)
# Out:
# Product_Category
# Beauty          27647.0
# Books           26523.0
# Clothing        85006.0
# Electronics     83358.0
# Furniture      128844.0
# Groceries       11978.0
# Sports          34484.0
# Toys            45270.0
# Name: Revenue, dtype: float64

# %% [markdown]
# Q8. Based on the revenue calculated for each product category, identify the top 3 categories with the
# highest revenue and the bottom 3 categories with the lowest revenue.

# %%
top3 = category_revenue.sort_values(ascending=False).head(3)
bottom3 = category_revenue.sort_values().head(3)

print("Top 3 Categories:\n", top3)
print("Bottom 3 Categories:\n", bottom3)
# Out:
# Top 3 Categories:
#  Product_Category
# Furniture      128844.0
# Clothing        85006.0
# Electronics     83358.0
# Name: Revenue, dtype: float64
# Bottom 3 Categories:
#  Product_Category
# Groceries    11978.0
# Books        26523.0
# Beauty       27647.0
# Name: Revenue, dtype: float64

# %% [markdown]
# Q9. Group the dataset by Region and calculate the total revenue generated in each region. Identify the
# region with the highest revenue and the region with the lowest revenue.

# %%
region_revenue = df.groupby('Region')['Revenue'].sum()
print(region_revenue)

print("Highest Revenue Region:", region_revenue.idxmax())
print("Lowest Revenue Region:", region_revenue.idxmin())
# Out:
# Region
# East     119875.0
# North    145387.0
# South     97471.0
# West      80377.0
# Name: Revenue, dtype: float64
# Highest Revenue Region: North
# Lowest Revenue Region: West

# %% [markdown]
# Q10. Extract the month from the Date column using Pandas and group the dataset by month to calculate the
# total monthly revenue. Also, calculate the mean, median, and standard deviation of the Revenue column
# using NumPy.

# %%
# Convert Date column to datetime
df['Date'] = pd.to_datetime(df['Date'], format='%d-%m-%Y')

# Extract month
df['Month'] = df['Date'].dt.month

# Group by month
monthly_revenue = df.groupby('Month')['Revenue'].sum()
print(monthly_revenue)

# Stats using NumPy
mean_rev = np.mean(df['Revenue'])
median_rev = np.median(df['Revenue'])
std_rev = np.std(df['Revenue'])

print("Mean Revenue:", mean_rev)
print("Median Revenue:", median_rev)
print("Std Dev Revenue:", std_rev)
# Out:
# Month
# 1     43994.0
# 2     33028.0
# 3     10557.0
# 4     56478.0
# 5     27915.0
# 6     28190.0
# 7     36919.0
# 8     76958.0
# 9     27437.0
# 10    38017.0
# 11    20278.0
# 12    43339.0
# Name: Revenue, dtype: float64
# Mean Revenue: 4978.76404494382
# Median Revenue: nan
# Std Dev Revenue: 4825.498053173284
